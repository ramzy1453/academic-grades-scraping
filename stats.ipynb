# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./deliberation_l3_acad.csv')
df
# Out:
#              full_name     matricule section  moyS1  credS1  moyS2  credS2  \
# 0          abib syphax  212133011895       A   0.14       0   0.00       0
# 1      afnoukh yassine  212131025548       A  15.45      30  15.67      30
# 2     aissaoui thiziri  212131019529       A  12.10      30  13.00      30
# 3       ait moussa ali  212131052977       A  13.62      30  15.96      30
# 4         akerma sedra  212131013600       A  13.36      30   0.00       0
# ..                 ...           ...     ...    ...     ...    ...     ...
# 304  tougherghi yacine  212131055325       C  12.22      30  11.75      30
# 305       touimer amel  202031053636       C  10.06      30   9.00      18
# 306     zazgad nesrine  182131084156       C  10.55      30  14.50      30
# 307      zekagh dounia  212131096145       C  10.06      30  14.02      30
# 308      zobiri yacine  212131010082       C  10.66      30  13.27      30
#
#      annuel  cred_annuel  admis
# 0      0.10            0  False
# ...

# %%
# par admis pie
df['admis'].value_counts().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    shadow=True,
    labels=['Admis', 'Non admis'],
    colors=['green', 'red'],
    explode=(0.1, 0)
)
# Out:
# <Axes: ylabel='count'>

# %%
df.sort_values(by='annuel', ascending=False)[['annuel', 'section']].head(10)
# Out:
#      annuel section
# 256   16.33       C
# 62    15.70       A
# 1     15.52       A
# 225   15.48       C
# 23    15.40       A
# 125   15.12       B
# 99    15.11       A
# 90    15.09       A
# 174   15.03       B
# 261   14.96       C

# %%
df.groupby('section')\
    .agg({'annuel': np.mean})
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3724\527268260.py:2: FutureWarning: The provided callable <function mean at 0x00000279E8ADA520> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   .agg({'annuel': np.mean})
#             annuel
# section
# A        11.451727
# B        11.817273
# C        11.672100
